# %% [markdown]
# # Basic List Operations

# %% [markdown]
# 1. Create a list of 5 numbers and add a new number to the end.

# %%
lst=[1,2,3,4,5]
lst.append(6)
print(lst)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# 2. Make a list of fruits and insert a fruit at the second position.

# %%
lst1=['apple','banana','grape']
lst1.insert(1,'orange')
print(lst1)
# Out:
# ['apple', 'orange', 'banana', 'grape']

# %% [markdown]
# 3. Create a list of names and remove one name from the list.

# %%
lst3=["Abhiraj","Harish","Gaurav"]
lst3.remove("Harish")
print(lst3)
# Out:
# ['Abhiraj', 'Gaurav']

# %% [markdown]
# 4. Create a list of 4 items and change the value at index 2.

# %%
items4=["pen","pencil","eraser","sharpener"]
items4[2]="penpencil"
print(items4)
# Out:
# ['pen', 'pencil', 'penpencil', 'sharpener']

# %% [markdown]
# 5. Make a list of numbers and print only the first three elements.

# %%
lst4=[10,20,30,40,50]
print(lst4[:3])
# Out:
# [10, 20, 30]

# %% [markdown]
# 6. Create a list of colors and find the index of a specific color.

# %%
lst_color=['red','green','blue','yellow']
print(lst_color.index('blue'))
# Out:
# 2

# %% [markdown]
# 7. Create a list of 10 numbers and print how many times “5” appears.

# %%
lst5=[1,2,5,4,5,6,5,7,5,5]
lst5.count(5)
# Out:
# 5

# %% [markdown]
# 8. Make a list of 6 items and delete the item at index 3.

# %%
lst6=['a','b','c','d','e','f']
del lst6[3]
print(lst6)
# Out:
# ['a', 'b', 'c', 'e', 'f']

# %% [markdown]
# 9. Create a list of animals and add three more animals using extend().

# %%
lst7=['lion','tiger','elephant']
lst8=['giraffe','zebra','monkey']
lst7.extend(lst8)
print(lst7)
# Out:
# ['lion', 'tiger', 'elephant', 'giraffe', 'zebra', 'monkey']

# %% [markdown]
# 10. Create a list and remove the last item using pop().

# %%
lst9=[3,1,4,2,5]
lst9.pop()
# Out:
# 5

# %% [markdown]
# 11. Create a list of prices and sort them in ascending order.

# %%
prices=[999, 88, 55, 777, 888]
prices.sort()
print(prices)
# Out:
# [55, 88, 777, 888, 999]

# %% [markdown]
# 12. Make a list of countries and reverse the order of the list.

# %%
countries = ["India", "USA", "Brazil", "Germany", "Japan"]
countries.reverse()
print(countries)
# Out:
# ['Japan', 'Germany', 'Brazil', 'USA', 'India']

# %% [markdown]
# 13. Create a list of words and check if “apple” is in the list.

# %%
fruits_1= ["banana", "mango", "apple", "cherry", "grapes"]
fruits_1.count("apple")
# Out:
# 1

# %% [markdown]
# 14. Create a list of numbers and print the largest and smallest number.

# %%
numbers = [10, 45, 2, 88,55,99]
largest_no = max(numbers)
smallest_no = min(numbers)
print("Largest number is:", largest_no)
print("Smallest number is:", smallest_no)
# Out:
# Largest number is: 99
# Smallest number is: 2

# %% [markdown]
# 15. Make a list of 5 items and print each item using a loop.

# %%
list_items  = ["pen", "notebook", "eraser", "pencil", "marker"]
for item in list_items:
    print(item)
# Out:
# pen
# notebook
# eraser
# pencil
# marker

# %% [markdown]
# 16. Create two lists and combine them into one list.

# %%
list11= [1, 2, 3]
list22= [4, 5, 6]

c= list11 + list22
print(c)


#or 

list11.extend(list22)
print(list11)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# 17. Make a list and replace the last item with a new value.

# %%
itm1 = ["apple", "banana", "cherry", "mango"]
itm1[-1] = "pineapple"
print(itm1)
# Out:
# ['apple', 'banana', 'cherry', 'pineapple']

# %% [markdown]
# 18. Create a list of numbers and print only the even numbers.

# %%
listofno= [11, 22, 33, 44, 55, 66, 77, 88, 99, 10] 
for num in listofno: 
    if num % 2 == 0:
        print(num)
# Out:
# 22
# 44
# 66
# 88
# 10

# %% [markdown]
# 19. Create a list and clear all items from the list.

# %%
fruits_lst= ["banana", "mango", "apple", "cherry", "grapes"]
fruits_lst.clear()
print(fruits_lst)
# Out:
# []

# %% [markdown]
# 20. Create a list of 5 values and copy it into another list.

# %%
list_og = [5, 10, 15, 20, 25]
new_list = list_og.copy()
print(new_list)
# Out:
# [5, 10, 15, 20, 25]
